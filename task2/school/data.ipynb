# %%
import pandas as pd

# Step 1: Import the CSV file into a Pandas DataFrame
file_path = './schools.csv'  # Replace with the actual path to your CSV file
df = pd.read_csv(file_path)

# %%
# Step 2: Display the structure of the DataFrame
print("DataFrame Info:")
print(df.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Code                       319 non-null    int64
#  1   School Name                319 non-null    object
#  2   Street                     319 non-null    object
#  3   Suburb                     319 non-null    object
#  4   State                      319 non-null    object
#  5   Postcode                   319 non-null    int64
#  6   Postal Street              319 non-null    object
#  7   Postal Suburb              319 non-null    object
#  8   Postal State               319 non-null    object
#  9   Postal Postcode            319 non-null    int64
#  10  Latitude                   319 non-null    float64
#  11  Longitude                  319 non-null    float64
#  12  Phone                      319 non-null    object
#  13  Education Region           319 non-null    object
#  14  Broad Classification       319 non-null    object
#  15  Classification Group       319 non-null    object
#  16  Low Year                   319 non-null    object
#  17  High Year                  319 non-null    object
#  18  KIN                        161 non-null    float64
#  19  PPR                        163 non-null    float64
#  20  Y01                        163 non-null    float64
#  21  Y02                        163 non-null    float64
#  22  Y03                        166 non-null    float64
#  23  Y04                        167 non-null    float64
#  24  Y05                        167 non-null    float64
#  25  Y06                        167 non-null    float64
#  26  UPR                        1 non-null      float64
#  27  Y07                        297 non-null    float64
#  28  Y08                        299 non-null    float64
#  29  Y09                        301 non-null    float64
#  30  Y10                        311 non-null    float64
#  31  Y11                        266 non-null    float64
#  32  Y12                        259 non-null    float64
#  33  USE                        2 non-null      float64
#  34  Total Students             319 non-null    int64
#  35  BE Score                   272 non-null    object
#  36  ICSEA                      262 non-null    float64
#  37  ATAR Rank                  139 non-null    float64
#  38  Median ATAR                139 non-null    float64
#  39  Eligible Year 12 students  139 non-null    float64
#  40  Students with ATAR         139 non-null    float64
#  41  % students with ATAR       139 non-null    float64
# dtypes: float64(24), int64(4), object(14)
# memory usage: 104.8+ KB
# None

# %%
# Step 3: Display the first few rows of the DataFrame
print("\nFirst few rows:")
df.head()
# Out:
# First few rows:
#    Code                    School Name                 Street      Suburb  \
# 0  4001      ALBANY SENIOR HIGH SCHOOL        1 CAMPBELL ROAD      ALBANY
# 1  1488        ALKIMOS BAPTIST COLLEGE  60 SEAGROVE BOULEVARD     MERRIWA
# 2  1277            ALL SAINTS' COLLEGE        28 EWING AVENUE  BULL CREEK
# 3  1478                         ALTA-1         12 WINTON ROAD   JOONDALUP
# 4  4002  APPLECROSS SENIOR HIGH SCHOOL             LINKS ROAD     ARDROSS
#
#   State  Postcode          Postal Street Postal Suburb Postal State  \
# 0    WA      6330        1 CAMPBELL ROAD        ALBANY           WA
# 1    WA      6030  60 SEAGROVE BOULEVARD       MERRIWA           WA
# 2    WA      6149        28 EWING AVENUE    BULL CREEK           WA
# 3    WA      6027             PO BOX 301  JOONDALUP DC           WA
# 4    WA      6153             LINKS ROAD       ARDROSS           WA
#
#    Postal Postcode  ...    Y12  USE Total Students BE Score   ICSEA ATAR Rank  \
# 0             6330  ...  124.0  NaN            977       88  1010.0     101.0
# 1             6030  ...   14.0  NaN            300       85  1035.0       NaN
# 2             6149  ...  146.0  NaN           1354       99  1154.0      21.0
# 3             6919  ...   57.0  NaN           1039      NaN     NaN       NaN
# 4             6153  ...  236.0  NaN           1665       98  1111.0      34.0
#
#   Median ATAR Eligible Year 12 students  Students with ATAR  \
# 0       72.80                     123.0                53.0
# 1         NaN                       NaN                 NaN
# 2       86.35                     146.0               120.0
# 3         NaN                       NaN                 NaN
# 4       84.30                     234.0               145.0
#
#    % students with ATAR
# 0                 43.09
# 1                   NaN
# 2                 82.19
# 3                   NaN
# 4                 61.97
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['Code', 'School Name', 'Street', 'Suburb', 'State', 'Postcode',
#        'Postal Street', 'Postal Suburb', 'Postal State', 'Postal Postcode',
#        'Latitude', 'Longitude', 'Phone', 'Education Region',
#        'Broad Classification', 'Classification Group', 'Low Year', 'High Year',
#        'KIN', 'PPR', 'Y01', 'Y02', 'Y03', 'Y04', 'Y05', 'Y06', 'UPR', 'Y07',
#        'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'USE', 'Total Students', 'BE Score',
#        'ICSEA', 'ATAR Rank', 'Median ATAR', 'Eligible Year 12 students',
#        'Students with ATAR', '% students with ATAR'],
#       dtype='object')

# %%
df2 = df[['School Name', 'Street', 'Suburb', 'State', 'Postcode',
    'Postal Street', 'Postal Suburb', 'Postal State', 'Postal Postcode',
    'Latitude', 'Longitude', 'Phone', 'Education Region',
    'Broad Classification', 'Classification Group', 'Low Year', 'High Year', 'Total Students', 'BE Score',
    'ICSEA', 'ATAR Rank', 'Median ATAR','% students with ATAR']].copy()

# %%
df2.head()
# Out:
#                      School Name                 Street      Suburb State  \
# 0      ALBANY SENIOR HIGH SCHOOL        1 CAMPBELL ROAD      ALBANY    WA
# 1        ALKIMOS BAPTIST COLLEGE  60 SEAGROVE BOULEVARD     MERRIWA    WA
# 2            ALL SAINTS' COLLEGE        28 EWING AVENUE  BULL CREEK    WA
# 3                         ALTA-1         12 WINTON ROAD   JOONDALUP    WA
# 4  APPLECROSS SENIOR HIGH SCHOOL             LINKS ROAD     ARDROSS    WA
#
#    Postcode          Postal Street Postal Suburb Postal State  \
# 0      6330        1 CAMPBELL ROAD        ALBANY           WA
# 1      6030  60 SEAGROVE BOULEVARD       MERRIWA           WA
# 2      6149        28 EWING AVENUE    BULL CREEK           WA
# 3      6027             PO BOX 301  JOONDALUP DC           WA
# 4      6153             LINKS ROAD       ARDROSS           WA
#
#    Postal Postcode   Latitude  ...  Broad Classification Classification Group  \
# 0             6330 -35.020448  ...   Senior High Schools    SECONDARY SCHOOLS
# 1             6030 -31.660328  ...      NON-GOVT SCHOOLS       NON-GOVERNMENT
# 2             6149 -32.049470  ...      NON-GOVT SCHOOLS       NON-GOVERNMENT
# 3             6919 -31.785372  ...      NON-GOVT SCHOOLS       NON-GOVERNMENT
# 4             6153 -32.029376  ...   Senior High Schools    SECONDARY SCHOOLS
#
#   Low Year High Year Total Students BE Score   ICSEA  ATAR Rank Median ATAR  \
# 0      Y07       Y12            977       88  1010.0      101.0       72.80
# 1      KIN       Y12            300       85  1035.0        NaN         NaN
# 2      KIN       Y12           1354       99  1154.0       21.0       86.35
# 3      Y08       Y12           1039      NaN     NaN        NaN         NaN
# 4      Y07       Y12           1665       98  1111.0       34.0       84.30
#
#    % students with ATAR
# 0                 43.09
# 1                   NaN
# 2                 82.19
# 3                   NaN
# 4                 61.97
#
# [5 rows x 23 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
df2.to_sql(name='schools', con=engine)
# Out:
# 319

# %%
import sqlite3

conn = sqlite3.connect('schools.db')
c = conn.cursor()

df.to_sql(name='school_info', con=conn, if_exists='append', index=False)

conn.commit()

# %%
import pandas as pd

class SchoolData():
    def __init__(self):
        self.file_path = '/schools.csv'
        self.df = pd.read_csv(self.file_path)

    def get_schools_from_csv(self):

        df2 = self.df[['School Name', 'Street', 'Suburb', 'State', 'Postcode',
            'Postal Street', 'Postal Suburb', 'Postal State', 'Postal Postcode',
            'Latitude', 'Longitude', 'Phone', 'Education Region',
            'Broad Classification', 'Classification Group', 'Low Year', 'High Year', 'Total Students', 'BE Score',
            'ICSEA', 'ATAR Rank', 'Median ATAR','% students with ATAR']].copy()
        
        return df2

# %%
from django.shortcuts import render
from django.shortcuts import render
import pandas as pd
from data import SchoolData

school_data = SchoolData()
all_schools = school_data.get_schools_from_csv()
print(all_schools)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 6
#       3 import pandas as pd
#       4 from data import SchoolData
# ----> 6 school_data = SchoolData()
#       7 all_schools = school_data.get_schools_from_csv()
#       8 print(all_schools)
#
# File c:\Users\Talent Match\Desktop\work\research\task2\school\data.py:6, in SchoolData.__init__(self)
#       4 def __init__(self):
#       5     self.file_path = '/schools.csv'
# ----> 6     self.df = pd.read_csv(self.file_path)
#
# File c:\Users\Talent Match\Desktop\work\research\task2\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Talent Match\Desktop\work\research\task2\venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Talent Match\Desktop\work\research\task2\venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Talent Match\Desktop\work\research\task2\venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Talent Match\Desktop\work\research\task2\venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/schools.csv'
